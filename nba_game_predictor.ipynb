# %% [markdown]
# <a href="https://colab.research.google.com/github/WayneGretzky1/CSCI-4521-Applied-Machine-Learning/blob/main/nba_game_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
nba_df = pd.read_csv("https://raw.githubusercontent.com/WayneGretzky1/CSCI-4521-Applied-Machine-Learning/refs/heads/main/cleaned.csv")
nba_df.head()
# Out:
#      gameid    gamedate  home_teamid  away_teamid  home_win_avg_prev5  \
# 0  22100064  2021-10-27   1610612746   1610612739                 0.4
# 1  22100072  2021-10-29   1610612751   1610612754                 0.6
# 2  22100073  2021-10-29   1610612748   1610612766                 1.0
# 3  22100077  2021-10-29   1610612747   1610612739                 0.2
# 4  22100071  2021-10-29   1610612761   1610612753                 0.4
#
#    away_win_avg_prev5  home_points_avg_prev5  away_points_avg_prev5  \
# 0                 0.6                  106.2                  104.8
# 1                 0.2                  103.6                  113.8
# 2                 0.8                  118.8                  114.0
# 3                 0.8                  106.6                  104.2
# 4                 0.2                  102.2                   96.0
#
#    home_opponent_points_avg_prev5  away_opponent_points_avg_prev5  ...  \
# ...
